# %% [markdown]
# # Webscraping: HTML Parsing

# %% [markdown]
# ## Environment setup

# %%
from google.colab import drive, files
import json
drive.mount('/mntDrive') 
path = "/mntDrive/My Drive/Colab Notebooks/"
# Out:
# Mounted at /mntDrive

# %% [markdown]
# ## The HTML story
#
# __HTML__ is a markup language, its basic build blocks are the `<tag>`s.<br>
# (Almost) every `<tag>` has two parts:
#
# - Opening `<tag>`
# - Closing `</tag>`
#
# Important html `<tag>`s:
#
# - `<html>some text</html>`
# - `<head>some text</head>`
# - `<body>some text</body>`
# - `<h1>some text</h1>`, ..., `<h6></h6>`
# - `<div>some text</div>`
# - `<p>some text</p>`
# - `<span>some text</span>`
# - `<section>some text</section>`
# - `<a href="">some text</a>`
# - `<img src="">`
# - `<br>`
# - ```
# <table>
#     <thead>
#         <tr>
#             <th></th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td></td>
#             ...
#         </tr>
#     </tbody>
# </table>
#  ```
# - `<ul></ul>` / `<ol></ol>` + `<li></li>`
#
# Tags can have different attributes and values associated with them:
# - `<a>`: href
# - `<img>`: src
#
# ## Let's see an end-to-end example:
#
# `<a href="https://evk.hu/"> This is the website of EVK </a>`
# - Tag: `<a>`
# - Attribute: `href`
# - Attribute value: `"https://evk.hu/"`
# - Text: `This is the website of EVK`
#
# <a href="https://evk.hu/"> This is the website of EVK </a>
#
# Most important methods:
# - `.find(tag, {attribute_name : attribute_value})`
# - `.find_all(tag, {attribute_name : attribute_value})`
# - `.get(attribute)`
# - `.get_text()`
# - `.select()`

# %% [markdown]
# ## Workflow of HTML based scraping
# Websites are rendered HTML codes.
# 1. Using Python, we request to receive these lines of codes with the `requests` package.
# 2. Inspect thet HTML code to find the tags you need.
# 3. Parse it with a package called `BeautifulSoup`
# 4. Find the adequate structure for data storage.

# %% [markdown]
# ## Let's get data from [hasznaltauto.hu](https://www.hasznaltauto.hu/)!
#
# - Choose a make and type and search for it.
# - Get the hyperlinks for all cars from the **first page**.

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.hasznaltauto...."

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'<!DOCTYPE html>\n<html lang="hu-HU">\n<head>\n    <link href="https://www.hasznaltauto.hu/favicon.ico" rel="shortcut icon" type="image/x-icon"; />\n    <link rel="stylesheet" href="https://bmh.jofogas.hu/hza/css-tracking.css" type="text/css" />\n    <meta charset="UTF-8"/>\n\n    <meta name="viewport" content="width=device-width, maximum-scale=1.0, minimum-scale=1.0, initial-scale=1.0, user-scalable=no" />\n    <meta name="format-detection" content="telephone=no">\n    <meta name="google" content="nositelinkssearchbox">\n    <script type="text/javascript" src="//try.abtasty.com/a08ec2f1cebf271595ee53f9ff0855fd.js"></script>\n    <script id="Cookiebot" src="https://consent.cookiebot.com/uc.js" data-cbid="f64b158b-39e4-4449-bb68-d72b6089afc5" type="text/javascript" data-culture="HU" async></script>\n\n        <title>Haszn\xc3\xa1ltaut\xc3\xb3.hu - Elad\xc3\xb3 haszn\xc3\xa1lt \xc3\xa9s \xc3\xbaj aut\xc3\xb3 keres\xc5\x91</title>\n\n    <script type="application/ld+json">{\n    "@context": {\n        "@vocab": "http://schema.org/"\n    },\n    "@type": "WebSite",\n    "name": "Haszn\xc3\xa1ltaut\xc3\xb3.hu",\n    "url": "https://www.hasznaltauto.hu"\n}</script><script type="application/ld+json">{\n    "@context": {\n        "@vocab": "http://schema.org/"\n    },\n    "@type": "BreadcrumbList",\n    "itemListElement": [\n        {\n            "@type": "ListItem",\n            "item": {\n                "@id": "https://www.hasznaltauto.hu/szemelyauto",\n                "name": "Szem\xc3\xa9lyaut\xc3\xb3"\n            },\n            "position": 1\n        },\n        {\n            "@type": "ListItem",\n            "item": {\n                "@id": "https://www.hasznaltauto.hu/szemelyauto/alfa_romeo",\n                "name": "ALFA ROMEO"\n            },\n            "position": 2\n        }\n    ]\n}</script><meta name="customtarget" content="dXNlcmRiX2lkPTQzJmthdGVnb3JpYT1zemVtZWx5YXV0byZneWFydG1hbnk9YWxmYV9yb21lbyZyZWdpbz1jdXM=">\n<meta property="og:title" content="Haszn\xc3\xa1ltaut\xc3\xb3.hu - Elad\xc3\xb3 haszn\xc3\xa1lt \xc3\xa9s \xc3\xbaj aut\xc3\xb3 keres\xc5\x91">\n<meta property="og:description" content="T\xc3\xb6bb mint 110060 j\xc3\xa1rm\xc5\xb1 Magyarorsz\xc3\xa1g legnagyobb haszn\xc3\xa1lt \xc3\xa9s \xc3\xbaj j\xc3\xa1rm\xc3\xbb adatb\xc3\xa1zis\xc3\xa1ban. Tal\xc3\xa1lja meg \xc3\x96n is a legjobb aj\xc3\xa1nlatot, vagy adja el g\xc3\xa9pj\xc3\xa1rm\xc5\xb1v\xc3\xa9t!">\n<meta property="og:url" content="https://www.hasznaltauto....">\n<meta property="og:image" content="https://hasznaltauto.medija.hu/new_test/images/og_image_default.png">\n<meta property="og:image:width" content="1200">\n<meta property="og:image:height" content="630">\n<meta property="fb:app_id" content="190697914343684">\n<meta property="og:type" content="website">\n<meta name="description" content="T\xc3\xb6bb mint 110060 j\xc3\xa1rm\xc5\xb1 Magyarorsz\xc3\xa1g legnagyobb haszn\xc3\xa1lt \xc3\xa9s \xc3\xbaj j\xc3\xa1rm\xc3\xbb adatb\xc3\xa1zis\xc3\xa1ban. Tal\xc3\xa1lja meg \xc3\x96n is a legjobb aj\xc3\xa1nlatot, vagy adja el g\xc3\xa9pj\xc3\xa1rm\xc5\xb1v\xc3\xa9t!">\n<meta name="robots" content="noindex">\n<meta name="keywords" content="expressz, aut\xc3\xb3-motor">\n<link href="https://www.hasznaltauto...." rel="canonical">\n<link href="https://hasznaltauto.medija.hu/new_test/images/og_image_default.png" rel="image_src">\n<link href="https://www.hasznaltauto...." rel="self">\n<link href="https://www.hasznaltauto...." rel="next">\n<link href="https://www.hasznaltauto...." rel="last">\n<link href="https://hasznaltauto.medija.hu/new_test/assets/sync-3fe6db0814e9a73281ee9b709e4047d5.css?v=1606410083" rel="stylesheet">\n<link href="https://hasznaltauto.medija.hu/new_test/assets/all-678521054f67e2f05351ad67ea0478bb.css?v=1606410098" rel="stylesheet">\n<link href="https://hasznaltauto.medija.hu/new_test/assets/print-dca8c1aeca0f72469893814f4ab81f7a.css?v=1606410119" rel="stylesheet" media="print">\n<script src="https://hasznaltauto.medija.hu/new_t ...

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
car_list = []
car_listing = soup.find("div", {"class" : "list-view"})
for tag in car_listing.find_all("h3"):
  new_car_link = tag.find("a").get("href")
  car_list.append(new_car_link)

# %%
car_list
# Out:
# ['https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_2_d_super_q4_automata-16383936',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0_super_q4_automata_my20_uj_modell_keszletrol-15934741',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0_super_q4_automata_my20_uj_modell_keszletrol-15934626',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_2_d_super_q4_automata_executive-navi-xenon-kamera-radar-16410056',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0_t_super_q4_automata-16256973',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0_t_super_q4_automata_afa-s-16188486',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio-16439923',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0_t_super_q4_automata-16006304',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0t_first_edition_q4_automata_garancialis-16312047',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0_t_super_edition_q4_automata_first_edition_at8_q4_afas-16420115',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0_t_super_q4_automata-16386593',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0_t_super_q4_automata_garancialis_53e_km_mo_-i_vezetett_szervizkonyv-16241977',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0_t_super_q4_automata-16396647',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0_t_super_q4_automata-16449074',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0t_first_edition_q4_automata_led_pdc_u-connect-16445606',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_2_dautomata-15849275',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0t_first_edition_q4_automata_vezetett_szervizkonyv-16319978',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0_t_super_q4_automata_facelift_13_ker-15342110',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_2_d_super_q4_automata_lusso_navi_bi-xenon-16445741',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0_t_super_q4_automata-15849428']

# %%
car_links = []
view_list = soup.find("div", {"class": 'list-view'})

# %%
for car in view_list.find_all("h3"):
  car_links.append(car
                   .find("a")
                   .get("href")
                   )
car_links
# Out:
# ['https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/giulia/alfa_romeo_giulia_2_2_d_veloce_q4_automata_afa-s_ar-16037970',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/giulia/alfa_romeo_giulia_2_0_veloce_q4_automata-16407950',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/giulia/alfa_romeo_giulia_super_1_6_felujitando_1972-14430282',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/giulia/alfa_romeo_giulia_2_2_d_super_szervizkonyv-csere_lehet-16107397',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/giulia/alfa_romeo_giulia_2_2_d_super-16447919',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/giulia/alfa_romeo_giulia_2_2_d_super_automata_felbor_navi_xenon_garancia-16257270',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/giulia/alfa_romeo_giulia_2_2_d_super-16153413',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/giulia/alfa_romeo_giulia_2_2_d_super_automata-16148656',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/giulia/alfa_romeo_giulia_2_2_d_super_afas_keveset_futott-16379232',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/giulia/alfa_romeo_giulia_2_2_d_super_automata-16436803',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/giulia/alfa_romeo_giulia_2_0automata_xenon_alu_74-ezer_km-16433736',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/giulia/alfa_romeo_giulia_2_2_d_super-16283820',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/giulia/alfa_romeo_giulia_2_0_super_automata_62_000km_mo_-i_vezetett_szervizkonyv-16167867',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/giulia/alfa_romeo_giulia_2_0automata-16364013',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/giulia/alfa_romeo_giulia_2_0_super_automata_winter_paket-16057661',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/giulia/alfa_romeo_giulia_super_1_6-16197517',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/giulia/alfa_romeo_giulia-16439920',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/giulia/alfa_romeo_giulia_2_2_dautomata_giulia_2_2_d_9_990_000_ft-tol-16001057',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/giulia/alfa_romeo_giulia_2_0_super_automata_facelift_13_ker-15339751',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/giulia/alfa_romeo_giulia-16439919']

# %% [markdown]
# ## Lab: Get articles from [portfolio.hu](https://portfolio.hu)!
# - Use the provided link which contains articles about a specific keyword
# - Get the hyperlinks to all the articles from the **first page**.

# %%
url = "https://www.portfolio.hu/kereses?q=soros&page=2"
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content)

# %%
article_section = soup.find('section', {'class': 'article-lists'})

# %%
for article in article_section.find_all("article"):
    print(article
           .find("h3")
           .find("a")
           .get("href")
           )

# %%
# Your code goes here

# %% [markdown]
# ## Let's get back to cars!
#
# - Using the links we collected eariler, we could get some more details as well.
# - Iterate over the hyperlinks, get more detils using `pd.read_html`.

# %%
import pandas as pd
url = "https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/giulia/alfa_romeo_giulia_2_0_super_automata_facelift_13_ker-15339751"

df_list = pd.read_html(url)

# %%
df = df_list[0]
df
# Out:
#                         Ár, költségek                    Ár, költségek.1
# 0                      Alaptípus ára:                      11 820 000 Ft
# 1                Extrákkal növelt ár:                      12 360 000 Ft
# 2                          Akciós ár:                      10 249 000 Ft
# 3                   Akció feltételei:     Egyeztetni szükséges a 20 4...
# 4                        Vételár EUR:                           € 28 375
# 5   Finanszírozás kalkulátor HIRDETÉS  Finanszírozás kalkulátor HIRDETÉS
# 6                    Általános adatok                   Általános adatok
# 7                           Átvehető:                              2020.
# 8                            Évjárat:                               2020
# 9                            Állapot:                             Normál
# 10                           Kivitel:                              Sedan
# 11                       Jármű adatok                       Jármű adatok
# 12               Kilométeróra állása:                               2 km
# 13           Szállítható szem. száma:                               5 fő
# 14                       Ajtók száma:                                  4
# 15                       Saját tömeg:                           1 429 kg
# 16                      Teljes tömeg:                           1 929 kg
# 17                       Csomagtartó:                          480 liter
# 18                     Klíma fajtája:           Digitális kétzónás klíma
# 19                       Motor adatok                       Motor adatok
# 20                         Üzemanyag:                             Benzin
# 21                  Hengerűrtartalom:                          1 995 cm³
# 22                      Teljesítmény:                     148 kW, 201 LE
# 23                 Henger-elrendezés:                              Soros
# 24                            Hajtás:                        Hátsó kerék
# 25             Sebességváltó fajtája:    Automata (8 fokozatú tiptronic)
# 26                           Okmányok                           Okmányok
# 27                  Okmányok jellege:                    Okmányok nélkül
# 28           Műszaki vizsga érvényes:                               2024
# 29                            Abroncs                            Abroncs
# 30                  Nyári gumi méret:                        225/50 R 17

# %%
df.rename(columns={"Ár, költségek": "features", "Ár, költségek.1":"values"}, inplace=True)
df
# Out:
#                              features                             values
# 0                      Alaptípus ára:                      11 820 000 Ft
# 1                Extrákkal növelt ár:                      12 360 000 Ft
# 2                          Akciós ár:                      10 249 000 Ft
# 3                   Akció feltételei:     Egyeztetni szükséges a 20 4...
# 4                        Vételár EUR:                           € 28 375
# 5   Finanszírozás kalkulátor HIRDETÉS  Finanszírozás kalkulátor HIRDETÉS
# 6                    Általános adatok                   Általános adatok
# 7                           Átvehető:                              2020.
# 8                            Évjárat:                               2020
# 9                            Állapot:                             Normál
# 10                           Kivitel:                              Sedan
# 11                       Jármű adatok                       Jármű adatok
# 12               Kilométeróra állása:                               2 km
# 13           Szállítható szem. száma:                               5 fő
# 14                       Ajtók száma:                                  4
# 15                       Saját tömeg:                           1 429 kg
# 16                      Teljes tömeg:                           1 929 kg
# 17                       Csomagtartó:                          480 liter
# 18                     Klíma fajtája:           Digitális kétzónás klíma
# 19                       Motor adatok                       Motor adatok
# 20                         Üzemanyag:                             Benzin
# 21                  Hengerűrtartalom:                          1 995 cm³
# 22                      Teljesítmény:                     148 kW, 201 LE
# 23                 Henger-elrendezés:                              Soros
# 24                            Hajtás:                        Hátsó kerék
# 25             Sebességváltó fajtája:    Automata (8 fokozatú tiptronic)
# 26                           Okmányok                           Okmányok
# 27                  Okmányok jellege:                    Okmányok nélkül
# 28           Műszaki vizsga érvényes:                               2024
# 29                            Abroncs                            Abroncs
# 30                  Nyári gumi méret:                        225/50 R 17

# %%
df.set_index('features', inplace=True)
df
# Out:
#                                                               values
# features
# Alaptípus ára:                                         11 820 000 Ft
# Extrákkal növelt ár:                                   12 360 000 Ft
# Akciós ár:                                             10 249 000 Ft
# Akció feltételei:                     Egyeztetni szükséges a 20 4...
# Vételár EUR:                                                € 28 375
# Finanszírozás kalkulátor HIRDETÉS  Finanszírozás kalkulátor HIRDETÉS
# Általános adatok                                    Általános adatok
# Átvehető:                                                      2020.
# Évjárat:                                                        2020
# Állapot:                                                      Normál
# Kivitel:                                                       Sedan
# Jármű adatok                                            Jármű adatok
# Kilométeróra állása:                                            2 km
# Szállítható szem. száma:                                        5 fő
# Ajtók száma:                                                       4
# Saját tömeg:                                                1 429 kg
# Teljes tömeg:                                               1 929 kg
# Csomagtartó:                                               480 liter
# Klíma fajtája:                              Digitális kétzónás klíma
# Motor adatok                                            Motor adatok
# Üzemanyag:                                                    Benzin
# Hengerűrtartalom:                                          1 995 cm³
# Teljesítmény:                                         148 kW, 201 LE
# Henger-elrendezés:                                             Soros
# Hajtás:                                                  Hátsó kerék
# Sebességváltó fajtája:               Automata (8 fokozatú tiptronic)
# Okmányok                                                    Okmányok
# Okmányok jellege:                                    Okmányok nélkül
# Műszaki vizsga érvényes:                                        2024
# Abroncs                                                      Abroncs
# Nyári gumi méret:                                        225/50 R 17

# %%
df.T
# Out:
# features Alaptípus ára: Extrákkal növelt ár:  ...  Abroncs Nyári gumi méret:
# values    11 820 000 Ft        12 360 000 Ft  ...  Abroncs       225/50 R 17
#
# [1 rows x 31 columns]

# %%
car_list
# Out:
# ['https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_2_d_super_q4_automata-16383936',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0_super_q4_automata_my20_uj_modell_keszletrol-15934741',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0_super_q4_automata_my20_uj_modell_keszletrol-15934626',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_2_d_super_q4_automata_executive-navi-xenon-kamera-radar-16410056',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0_t_super_q4_automata-16256973',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0_t_super_q4_automata_afa-s-16188486',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio-16439923',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0_t_super_q4_automata-16006304',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0t_first_edition_q4_automata_garancialis-16312047',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0_t_super_edition_q4_automata_first_edition_at8_q4_afas-16420115',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0_t_super_q4_automata-16386593',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0_t_super_q4_automata_garancialis_53e_km_mo_-i_vezetett_szervizkonyv-16241977',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0_t_super_q4_automata-16396647',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0_t_super_q4_automata-16449074',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0t_first_edition_q4_automata_led_pdc_u-connect-16445606',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_2_dautomata-15849275',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0t_first_edition_q4_automata_vezetett_szervizkonyv-16319978',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0_t_super_q4_automata_facelift_13_ker-15342110',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_2_d_super_q4_automata_lusso_navi_bi-xenon-16445741',
#  'https://www.hasznaltauto.hu/szemelyauto/alfa_romeo/stelvio/alfa_romeo_stelvio_2_0_t_super_q4_automata-15849428']

# %%
dataframes = []
for car_link in car_list:
  df = pd.read_html(car_link)[0]
  df.rename(columns={"Ár, költségek": "features", "Ár, költségek.1":"values"}, inplace=True)
  df.set_index('features', inplace=True)
  dataframes.append(df.T)

# %%
final = pd.concat(dataframes)
final.to_csv(path + "cars.csv")

# %%
final
# Out:
#              Vételár:  ...  Ellenőrzöm
# values   8 490 000 Ft  ...         NaN
# values            NaN  ...         NaN
# values            NaN  ...         NaN
# values   8 999 000 Ft  ...         NaN
# values   8 999 000 Ft  ...         NaN
# values   9 699 000 Ft  ...         NaN
# values  10 390 000 Ft  ...         NaN
# values  10 490 000 Ft  ...         NaN
# values  10 890 000 Ft  ...         NaN
# values  10 990 000 Ft  ...         NaN
# values  10 990 000 Ft  ...         NaN
# values  10 990 000 Ft  ...         NaN
# values  10 800 000 Ft  ...         NaN
# values  11 090 000 Ft  ...  Ellenőrzöm
# values  11 199 999 Ft  ...         NaN
# values            NaN  ...         NaN
# values  11 990 000 Ft  ...  Ellenőrzöm
# values            NaN  ...         NaN
# values  12 399 999 Ft  ...         NaN
# values            NaN  ...         NaN
#
# [20 rows x 45 columns]
