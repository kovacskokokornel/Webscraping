# %% [markdown]
# # This is a system check notebook
#
# 1. Write your name in the first line of the command below.
# 2. Run the below cell by pressing _Shift + Enter_.

# %%
your_name = "<FILL_IN_WITH_NAME>"
print(f"Hello, {your_name}. Welcome to the course!")
